# %%
import pandas as pd
import numpy as np

# %%
excel = pd.ExcelFile('random_data.xlsx')
df1 = pd.read_excel(excel, 'house_details')
df2 = pd.read_excel(excel, 'dates_price')
df3 = pd.read_excel(excel, 'zip')

# %%
df1.head()
# Out:
#            id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0  ab67xvd45a  Single Family    3     2           Y           Y     0.120
# 1  CGfuTAja6e   Multi Family    2     2           Y           N     0.080
# 2  r2BHN1B6fR  Single Family    2     1           Y           N     0.085
# 3  ni8kQpBlI7           Land    0     0           N           N     1.100
# 4  h11DyplDcR           Land    1     4           Y           Y     1.882
#
#             city       state  zip_code  house_size
# 0      Hammonton  New Jersey      8037         930
# 1  Hudson County  New Jersey      8037         560
# 2      Hammonton  New Jersey      8037         570
# 3      Hammonton  New Jersey      8037        1200
# 4  Atlantic City  New Jersey      8405         821

# %%
df2.head()
# Out:
#            id listing_date  listing_price  sold_date  actual_sold_price  \
# 0  04aEnREszK   2020-12-08          64822 2020-05-26             441028
# 1  08wNoarwIa   2021-01-03         101486 2020-02-09              37339
# 2  0AVQltLwXI   2020-09-28         258781 2020-03-06             448317
# 3  0BZsw7ywlG   2020-01-23         373258 2020-07-24             269657
# 4  0MSthRdnuw   2020-04-19         371166 2020-08-01             256600
#
#     status
# 0  Pending
# 1  Pending
# 2  Pending
# 3  Pending
# 4     Sold

# %%
df3.head()
# Out:
#             city       state  zip_code  zip_code_population
# 0      Hammonton  New Jersey      8037                23729
# 1  Atlantic City  New Jersey      8405                45600
# 2  Basking Ridge  New Jersey      7920                 7000
# 3  Hudson County  New Jersey      7305                12700
# 4  Atlantic City  New Jersey      8404                 8900

# %%
# sort df entries by id
df1.sort_values(by=['id'], inplace=True)
df1.head()
# Out:
#              id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 269  04aEnREszK           Land    1     1           Y           N     1.998
# 323  08wNoarwIa  Single Family    5     4           N           Y     4.473
# 240  0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 479  0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 218  0MSthRdnuw           Land    2     2           Y           N     1.086
#
#               city       state  zip_code  house_size
# 269      Elizabeth  New Jersey      7215        1078
# 323  Atlantic City  New Jersey      8405         585
# 240  Hudson County  New Jersey      7305         216
# 479  Atlantic City  New Jersey      8405         424
# 218      Elizabeth  New Jersey      7216        2090

# %%
# reset index df1 entries
df1.reset_index(drop=True, inplace=True)

# %%
df1.drop(columns=['index'], inplace=True)

# %%
df1
# Out:
#              id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0    04aEnREszK           Land    1     1           Y           N     1.998
# 1    08wNoarwIa  Single Family    5     4           N           Y     4.473
# 2    0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 3    0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 4    0MSthRdnuw           Land    2     2           Y           N     1.086
# ..          ...            ...  ...   ...         ...         ...       ...
# 499  zeB0TPYpc0  Single Family    5     1           N           N     1.666
# 500  zfQ5u9Fmk7           Land    3     0           Y           N     2.552
# 501  zgBr2x60p4           Land    3     3           Y           N     4.542
# 502  zpiyYG8QFW  Single Family    4     2           Y           Y     7.225
# 503  zvEyQmCyDz  Single Family    1     1           N           N     8.265
#
#               city       state  zip_code  house_size
# ...

# %%
df2.sort_values(by=['id'], inplace=True)

# %%
df2.head()
# Out:
#            id listing_date  listing_price  sold_date  actual_sold_price  \
# 0  04aEnREszK   2020-12-08          64822 2020-05-26             441028
# 1  08wNoarwIa   2021-01-03         101486 2020-02-09              37339
# 2  0AVQltLwXI   2020-09-28         258781 2020-03-06             448317
# 3  0BZsw7ywlG   2020-01-23         373258 2020-07-24             269657
# 4  0MSthRdnuw   2020-04-19         371166 2020-08-01             256600
#
#     status
# 0  Pending
# 1  Pending
# 2  Pending
# 3  Pending
# 4     Sold

# %%
df1.isnull().sum()
# Out:
# id             0
# home_type      0
# bed            0
# bath           0
# play_ground    0
# swming_tank    0
# acre_lot       0
# city           0
# state          0
# zip_code       0
# house_size     0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# id                   0
# listing_date         0
# listing_price        0
# sold_date            0
# actual_sold_price    0
# status               0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# city                   0
# state                  0
# zip_code               0
# zip_code_population    0
# dtype: int64

# %%
df1
# Out:
#              id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0    04aEnREszK           Land    1     1           Y           N     1.998
# 1    08wNoarwIa  Single Family    5     4           N           Y     4.473
# 2    0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 3    0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 4    0MSthRdnuw           Land    2     2           Y           N     1.086
# ..          ...            ...  ...   ...         ...         ...       ...
# 499  zeB0TPYpc0  Single Family    5     1           N           N     1.666
# 500  zfQ5u9Fmk7           Land    3     0           Y           N     2.552
# 501  zgBr2x60p4           Land    3     3           Y           N     4.542
# 502  zpiyYG8QFW  Single Family    4     2           Y           Y     7.225
# 503  zvEyQmCyDz  Single Family    1     1           N           N     8.265
#
#               city       state  zip_code  house_size
# ...

# %%
import matplotlib.pyplot as plt

# %%
df1['city'].value_counts().plot(kind='bar')

# %%
df1['state'].value_counts()
# Out:
# New Jersey    504
# Name: state, dtype: int64

# %%
df1['play_ground'].value_counts()
# Out:
# Y    270
# N    234
# Name: play_ground, dtype: int64

# %%
df1['swming_tank'].value_counts()
# Out:
# N    261
# Y    243
# Name: swming_tank, dtype: int64

# %%
# plot play_ground vs swiming_tank
df[df['play_ground'] == 'Y']['swming_tank'].value_counts().plot(kind='bar', title='swiming_tank stats for houses with play_ground')

# %%
df[df['play_ground'] == 'N']['swming_tank'].value_counts().plot(kind='bar', title='swiming_tank stats for houses without play_ground')

# %%
df1.head()
# Out:
#            id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0  04aEnREszK           Land    1     1           Y           N     1.998
# 1  08wNoarwIa  Single Family    5     4           N           Y     4.473
# 2  0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 3  0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 4  0MSthRdnuw           Land    2     2           Y           N     1.086
#
#             city       state  zip_code  house_size
# 0      Elizabeth  New Jersey      7215        1078
# 1  Atlantic City  New Jersey      8405         585
# 2  Hudson County  New Jersey      7305         216
# 3  Atlantic City  New Jersey      8405         424
# 4      Elizabeth  New Jersey      7216        2090

# %%
df1['bed'].value_counts()
# Out:
# 1    106
# 5     90
# 3     89
# 4     79
# 2     73
# 0     67
# Name: bed, dtype: int64

# %%
df1['bath'].value_counts()
# Out:
# 3    111
# 4    106
# 2     98
# 0     98
# 1     91
# Name: bath, dtype: int64

# %%
df1 = df1.merge(df2, on='id', how='left')
df1
# Out:
#              id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0    04aEnREszK           Land    1     1           Y           N     1.998
# 1    08wNoarwIa  Single Family    5     4           N           Y     4.473
# 2    0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 3    0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 4    0MSthRdnuw           Land    2     2           Y           N     1.086
# ..          ...            ...  ...   ...         ...         ...       ...
# 499  zeB0TPYpc0  Single Family    5     1           N           N     1.666
# 500  zfQ5u9Fmk7           Land    3     0           Y           N     2.552
# 501  zgBr2x60p4           Land    3     3           Y           N     4.542
# 502  zpiyYG8QFW  Single Family    4     2           Y           Y     7.225
# 503  zvEyQmCyDz  Single Family    1     1           N           N     8.265
#
# ...

# %%
sorted(df1['zip_code'].unique())
# Out:
# [7208, 7215, 7216, 7305, 7920, 8037, 8402, 8404, 8405]

# %%
sorted(df3['zip_code'])
# Out:
# [7208, 7215, 7216, 7305, 7920, 8037, 8037, 8402, 8404, 8405]

# %%
df3
# Out:
#             city       state  zip_code  zip_code_population
# 0      Hammonton  New Jersey      8037                23729
# 1  Atlantic City  New Jersey      8405                45600
# 2  Basking Ridge  New Jersey      7920                 7000
# 3  Hudson County  New Jersey      7305                12700
# 4  Atlantic City  New Jersey      8404                 8900
# 5      Hammonton  New Jersey      8037                23000
# 6  Atlantic City  New Jersey      8402                 6500
# 7      Elizabeth  New Jersey      7216                 2100
# 8      Elizabeth  New Jersey      7208                 6890
# 9      Elizabeth  New Jersey      7215                26500

# %%
# find the data enrty with zip_code 8037 and city Hudson County
df1[(df1['zip_code'] == 8037) & (df1['city'] == 'Hudson County')]
# Out:
#              id     home_type  bed  bath play_ground swming_tank  acre_lot  \
# 106  CGfuTAja6e  Multi Family    2     2           Y           N      0.08
#
#               city       state  zip_code  ...  listing_date_x listing_price_x  \
# 106  Hudson County  New Jersey      8037  ...      2020-01-10          128000
#
#      sold_date_x actual_sold_price_x  status_x listing_date_y listing_price_y  \
# 106   2020-04-05              129000      Sold     2020-01-10          128000
#
#      sold_date_y actual_sold_price_y  status_y
# 106   2020-04-05              129000      Sold
#
# [1 rows x 21 columns]

# %%
df1[df1['zip_code'] == 8037]['city'].unique()
# Out:
# array(['Hammonton', 'Hudson County'], dtype=object)

# %%
df1[df1['zip_code'] == 8037]
# Out:
#              id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 11   16Oe3ClPfg   Multi Family    5     3           Y           N     7.191
# 12   1Jg9NzvXl7   Multi Family    2     4           Y           Y     2.728
# 21   1wzJ09ekFN  Single Family    1     1           N           Y     1.715
# 27   2mHTbppx4r   Multi Family    4     4           N           Y     6.161
# 29   38s5SUTZBj  Single Family    0     2           N           Y     7.492
# ..          ...            ...  ...   ...         ...         ...       ...
# 434  ppXHwqyZQU   Multi Family    1     0           Y           N     4.502
# 443  qzKYp5Duov  Single Family    3     3           Y           Y     8.492
# 444  r2BHN1B6fR  Single Family    2     1           Y           N     0.085
# 499  zeB0TPYpc0  Single Family    5     1           N           N     1.666
# 502  zpiyYG8QFW  Single Family    4     2           Y           Y     7.225
#
# ...

# %%
df1 = df1.merge(df3, on='zip_code', how='left')

# %%
df1.head()
# Out:
#            id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0  04aEnREszK           Land    1     1           Y           N     1.998
# 1  08wNoarwIa  Single Family    5     4           N           Y     4.473
# 2  0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 3  0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 4  0MSthRdnuw           Land    2     2           Y           N     1.086
#
#           city_x     state_x  zip_code  ...  actual_sold_price_x status_x  \
# 0      Elizabeth  New Jersey      7215  ...               441028  Pending
# 1  Atlantic City  New Jersey      8405  ...                37339  Pending
# 2  Hudson County  New Jersey      7305  ...               448317  Pending
# 3  Atlantic City  New Jersey      8405  ...               269657  Pending
# 4      Elizabeth  New Jersey      7216  ...               256600     Sold
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'home_type', 'bed', 'bath', 'play_ground', 'swming_tank',
#        'acre_lot', 'city_x', 'state_x', 'zip_code', 'house_size',
#        'listing_date_x', 'listing_price_x', 'sold_date_x',
#        'actual_sold_price_x', 'status_x', 'listing_date_y', 'listing_price_y',
#        'sold_date_y', 'actual_sold_price_y', 'status_y', 'city_y', 'state_y',
#        'zip_code_population'],
#       dtype='object')

# %%
cols1 = ['city_x', 'state_x', 'listing_date_x', 'listing_price_x', 'sold_date_x', 'actual_sold_price_x', 'status_x']
cols2 = ['city_y', 'state_y', 'listing_date_y', 'listing_price_y', 'sold_date_y', 'actual_sold_price_y', 'status_y']

for i in range(len(cols1)):
    print(cols1[i] + ": " + str(df1[df1[cols1[i]] != df1[cols2[i]]].count()[0]))
# Out:
# city_x: 2
# state_x: 0
# listing_date_x: 0
# listing_price_x: 0
# sold_date_x: 0
# actual_sold_price_x: 0
# status_x: 0

# %%
df1[df1['city_x'] != df1['city_y']]
# Out:
#              id     home_type  bed  bath play_ground swming_tank  acre_lot  \
# 117  CGfuTAja6e  Multi Family    2     2           Y           N      0.08
# 118  CGfuTAja6e  Multi Family    2     2           Y           N      0.08
#
#             city_x     state_x  zip_code  ...  actual_sold_price_x status_x  \
# 117  Hudson County  New Jersey      8037  ...               129000     Sold
# 118  Hudson County  New Jersey      8037  ...               129000     Sold
#
#      listing_date_y listing_price_y  sold_date_y actual_sold_price_y status_y  \
# 117      2020-01-10          128000   2020-04-05              129000     Sold
# 118      2020-01-10          128000   2020-04-05              129000     Sold
#
#         city_y     state_y  zip_code_population
# 117  Hammonton  New Jersey                23729
# 118  Hammonton  New Jersey                23000
#
# [2 rows x 24 columns]

# %%
df1.columns
# Out:
# Index(['id', 'home_type', 'bed', 'bath', 'play_ground', 'swming_tank',
#        'acre_lot', 'city_x', 'state_x', 'zip_code', 'house_size',
#        'listing_date_x', 'listing_price_x', 'sold_date_x',
#        'actual_sold_price_x', 'status_x', 'listing_date_y', 'listing_price_y',
#        'sold_date_y', 'actual_sold_price_y', 'status_y', 'city_y', 'state_y',
#        'zip_code_population'],
#       dtype='object')

# %%
df = df1[['id', 'home_type', 'bed', 'bath', 'play_ground', 'swming_tank', 'acre_lot', 'house_size', 'city_y', 'state_y',
            'zip_code', 'listing_date_x', 'listing_price_x', 'sold_date_x', 'actual_sold_price_x', 'status_x']]

df.head()
# Out:
#            id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0  04aEnREszK           Land    1     1           Y           N     1.998
# 1  08wNoarwIa  Single Family    5     4           N           Y     4.473
# 2  0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 3  0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 4  0MSthRdnuw           Land    2     2           Y           N     1.086
#
#    house_size         city_y     state_y  zip_code listing_date_x  \
# 0        1078      Elizabeth  New Jersey      7215     2020-12-08
# 1         585  Atlantic City  New Jersey      8405     2021-01-03
# 2         216  Hudson County  New Jersey      7305     2020-09-28
# 3         424  Atlantic City  New Jersey      8405     2020-01-23
# 4        2090      Elizabeth  New Jersey      7216     2020-04-19
#
#    listing_price_x sold_date_x  actual_sold_price_x status_x
# 0            64822  2020-05-26               441028  Pending
# ...

# %%
# rename columns
df.rename(columns={'city_y': 'city', 
                    'state_y': 'state',
                    'listing_date_x': 'listing_date',
                    'listing_price_x': 'listing_price',
                    'sold_date_x': 'sold_date',
                    'actual_sold_price_x': 'actual_sold_price',
                    'status_x': 'status'}, 
                    inplace=True)
# Out:
# C:\Users\praya\AppData\Local\Temp\ipykernel_32100\3090718873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'city_y': 'city',

# %%
df.head()
# Out:
#            id      home_type  bed  bath play_ground swming_tank  acre_lot  \
# 0  04aEnREszK           Land    1     1           Y           N     1.998
# 1  08wNoarwIa  Single Family    5     4           N           Y     4.473
# 2  0AVQltLwXI  Single Family    4     2           Y           Y     2.826
# 3  0BZsw7ywlG  Single Family    2     2           N           Y     3.006
# 4  0MSthRdnuw           Land    2     2           Y           N     1.086
#
#    house_size           city       state  zip_code listing_date  \
# 0        1078      Elizabeth  New Jersey      7215   2020-12-08
# 1         585  Atlantic City  New Jersey      8405   2021-01-03
# 2         216  Hudson County  New Jersey      7305   2020-09-28
# 3         424  Atlantic City  New Jersey      8405   2020-01-23
# 4        2090      Elizabeth  New Jersey      7216   2020-04-19
#
#    listing_price  sold_date  actual_sold_price   status
# 0          64822 2020-05-26             441028  Pending
# ...

# %%
df.shape
# Out:
# (565, 16)

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue='status', size=2.5)
# Out:
# c:\Users\praya\.conda\envs\tf\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# heatmap
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='RdYlGn', linewidths=0.2)
# Out:
# C:\Users\praya\AppData\Local\Temp\ipykernel_32100\4058716700.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='RdYlGn', linewidths=0.2)

# %%
df[df['actual_sold_price'] > df['listing_price']]['status'].value_counts()
# Out:
# Pending    146
# Sold       136
# Name: status, dtype: int64
